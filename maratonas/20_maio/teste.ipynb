# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
aeronaves = pd.read_csv('aeronave.csv', header=0, sep=";", encoding="latin-1")

# %%
aeronaves.value_counts('aeronave_fabricante')
# Out:
# aeronave_fabricante
# EMBRAER                                1708
# CESSNA AIRCRAFT                        1700
# BOEING                                 1425
# AIRBUS                                 1373
# PIPER AIRCRAFT                          738
#                                        ...
# SPEEDBIRD                                 1
# SPS TRADING IMP. E EXPORTADORA LTDA       1
# VINICIUS DE MIRANDA                       1
# Vinicius Marini Ferreira                  1
# WACO AIRCRAFT                             1
# Name: count, Length: 404, dtype: int64
